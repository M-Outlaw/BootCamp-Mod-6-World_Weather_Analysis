# %%
# Import the dependencies and API key.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time

# %%
#3 Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
#4 Get the nearest city for all of coordinates
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 742

# %%
#5 and 6 Make API call with the OpenWeatherMap and retrieving weather data for cities 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_data = []

record_count = 1
set_count = 1

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | vardo
# Processing Record 6 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | emerald
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | biak
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | joshimath
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | great yarmouth
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | kuruman
# Processing Record 22 of Set 1 | cayenne
# Processing Record 23 of Set 1 | henties bay
# Processing Record 24 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | saquena
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | camana
# Processing Record 32 of Set 1 | poum
# Processing Record 33 of Set 1 | psikhikon
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | ust-nera
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | neuenhagen
# Processing Record 40 of Set 1 | zhigalovo
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | romitan
# Processing Record 43 of Set 1 | anadyr
# Processing Record 44 of Set 1 | sao filipe
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | hambantota
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | vila franca do campo
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | price
# Processing Record 1 of Set 2 | clyde river
# Processing Record 2 of Set 2 | san carlos de bariloche
# Processing Record 3 of Set 2 | kismayo
# Processing Record 4 of Set 2 | pangnirtung
# Processing Record 5 of Set 2 | pueblo
# Processing Record 6 of Set 2 | waipawa
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | anloga
# Processing Record 9 of Set 2 | erdenet
# Processing Record 10 of Set 2 | dudinka
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | axim
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | los llanos de aridane
# Processing Record 16 of Set 2 | tefe
# Processing Record 17 of Set 2 | lokosovo
# Processing Record 18 of Set 2 | saint-jean-de-dieu
# City not found. Skipping...
# Processing Record 19 of Set 2 | namatanai
# Processing Record 20 of Set 2 | balkanabat
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | mana
# Processing Record 23 of Set 2 | gore
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | tianpeng
# Processing Record 26 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | mitsamiouli
# Processing Record 30 of Set 2 | concordia
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | kodiak
# Processing Record 36 of Set 2 | lasa
# Processing Record 37 of Set 2 | horsham
# Processing Record 38 of Set 2 | avarua
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | novopokrovka
# Processing Record 42 of Set 2 | san quintin
# Processing Record 43 of Set 2 | nome
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | rio grande
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | flinders
# Processing Record 49 of Set 2 | barabinsk
# Processing Record 50 of Set 2 | codrington
# Processing Record 1 of Set 3 | coquimbo
# Processing Record 2 of Set 3 | teya
# Processing Record 3 of Set 3 | sinnamary
# Processing Record 4 of Set 3 | kerema
# Processing Record 5 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 3 | pokhara
# Processing Record 7 of Set 3 | labuhan
# Processing Record 8 of Set 3 | kirakira
# Processing Record 9 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 3 | punta arenas
# Processing Record 12 of Set 3 | chkalovskoye
# Processing Record 13 of Set 3 | luderitz
# Processing Record 14 of Set 3 | alta floresta
# Processing Record 15 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 16 of Set 3 | pisco
# Processing Record 17 of Set 3 | daru
# Processing Record 18 of Set 3 | panguna
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | vigrestad
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | bukachacha
# Processing Record 23 of Set 3 | lixourion
# Processing Record 24 of Set 3 | orta nova
# Processing Record 25 of Set 3 | omsukchan
# Processing Record 26 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 27 of Set 3 | sterling
# Processing Record 28 of Set 3 | kavaratti
# Processing Record 29 of Set 3 | okhotsk
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | pingzhuang
# Processing Record 32 of Set 3 | leningradskiy
# Processing Record 33 of Set 3 | lagoa
# Processing Record 34 of Set 3 | hermanus
# Processing Record 35 of Set 3 | husavik
# Processing Record 36 of Set 3 | port lincoln
# Processing Record 37 of Set 3 | bereda
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | yar-sale
# Processing Record 40 of Set 3 | iralaya
# Processing Record 41 of Set 3 | puerto ayora
# Processing Record 42 of Set 3 | picos
# Processing Record 43 of Set 3 | intipuca
# Processing Record 44 of Set 3 | iqaluit
# Processing Record 45 of Set 3 | ushtobe
# Processing Record 46 of Set 3 | porto novo
# Processing Record 47 of Set 3 | kungurtug
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | menongue
# Processing Record 50 of Set 3 | gizo
# Processing Record 1 of Set 4 | shelburne
# Processing Record 2 of Set 4 | maldonado
# Processing Record 3 of Set 4 | oranjemund
# Processing Record 4 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 4 | ayorou
# Processing Record 6 of Set 4 | ararat
# Processing Record 7 of Set 4 | broome
# Processing Record 8 of Set 4 | akyab
# Processing Record 9 of Set 4 | milingimbi
# City not found. Skipping...
# Processing Record 10 of Set 4 | laguna
# Processing Record 11 of Set 4 | urumqi
# Processing Record 12 of Set 4 | sao jose da coroa grande
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | santarem
# Processing Record 15 of Set 4 | esperance
# Processing Record 16 of Set 4 | college
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | palmer
# Processing Record 19 of Set 4 | kapuskasing
# Processing Record 20 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 21 of Set 4 | calama
# Processing Record 22 of Set 4 | dunedin
# Processing Record 23 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 4 | soyo
# Processing Record 25 of Set 4 | luanda
# Processing Record 26 of Set 4 | portland
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | lorengau
# Processing Record 29 of Set 4 | omama
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | rudnogorsk
# Processing Record 32 of Set 4 | ponta do sol
# Processing Record 33 of Set 4 | coahuayana
# Processing Record 34 of Set 4 | kranea elassonos
# Processing Record 35 of Set 4 | constitucion
# Processing Record 36 of Set 4 | batsfjord
# Processing Record 37 of Set 4 | chunskiy
# Processing Record 38 of Set 4 | alice springs
# Processing Record 39 of Set 4 | belmonte
# Processing Record 40 of Set 4 | puerto del rosario
# Processing Record 41 of Set 4 | carballo
# Processing Record 42 of Set 4 | chara
# Processing Record 43 of Set 4 | lahat
# Processing Record 44 of Set 4 | bilibino
# Processing Record 45 of Set 4 | constantine
# Processing Record 46 of Set 4 | khatanga
# Processing Record 47 of Set 4 | bambous virieux
# Processing Record 48 of Set 4 | zyuzelskiy
# Processing Record 49 of Set 4 | saint paul
# Processing Record 50 of Set 4 | mayya
# Processing Record 1 of Set 5 | necochea
# Processing Record 2 of Set 5 | mazagao
# Processing Record 3 of Set 5 | saskylakh
# Processing Record 4 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 5 | bima
# Processing Record 7 of Set 5 | terrace
# Processing Record 8 of Set 5 | meulaboh
# Processing Record 9 of Set 5 | kimbe
# Processing Record 10 of Set 5 | cabedelo
# Processing Record 11 of Set 5 | puri
# Processing Record 12 of Set 5 | trelleborg
# Processing Record 13 of Set 5 | cochrane
# Processing Record 14 of Set 5 | egvekinot
# Processing Record 15 of Set 5 | katobu
# Processing Record 16 of Set 5 | pevek
# Processing Record 17 of Set 5 | manadhoo
# Processing Record 18 of Set 5 | jiaozuo
# Processing Record 19 of Set 5 | amazar
# Processing Record 20 of Set 5 | fort frances
# Processing Record 21 of Set 5 | baripada
# Processing Record 22 of Set 5 | port hardy
# Processing Record 23 of Set 5 | bonavista
# Processing Record 24 of Set 5 | sitka
# Processing Record 25 of Set 5 | kaniama
# Processing Record 26 of Set 5 | saint anthony
# Processing Record 27 of Set 5 | dingle
# Processing Record 28 of Set 5 | jilib
# Processing Record 29 of Set 5 | saint-georges
# Processing Record 30 of Set 5 | provideniya
# Processing Record 31 of Set 5 | haguenau
# Processing Record 32 of Set 5 | catamarca
# Processing Record 33 of Set 5 | san cristobal
# Processing Record 34 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 5 | kamenka
# Processing Record 36 of Set 5 | nabire
# Processing Record 37 of Set 5 | rundu
# Processing Record 38 of Set 5 | araouane
# Processing Record 39 of Set 5 | omboue
# Processing Record 40 of Set 5 | hovd
# Processing Record 41 of Set 5 | kanker
# Processing Record 42 of Set 5 | mahon
# Processing Record 43 of Set 5 | ostrovnoy
# Processing Record 44 of Set 5 | tura
# Processing Record 45 of Set 5 | nikolskoye
# Processing Record 46 of Set 5 | kabalo
# Processing Record 47 of Set 5 | cartagena
# Processing Record 48 of Set 5 | adrar
# Processing Record 49 of Set 5 | nizwa
# Processing Record 50 of Set 5 | hofn
# Processing Record 1 of Set 6 | chingirlau
# Processing Record 2 of Set 6 | nahavand
# Processing Record 3 of Set 6 | wanning
# Processing Record 4 of Set 6 | san patricio
# Processing Record 5 of Set 6 | vangaindrano
# Processing Record 6 of Set 6 | den helder
# Processing Record 7 of Set 6 | saint george
# Processing Record 8 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 9 of Set 6 | jiuquan
# Processing Record 10 of Set 6 | saldanha
# Processing Record 11 of Set 6 | qaqortoq
# Processing Record 12 of Set 6 | longyearbyen
# Processing Record 13 of Set 6 | santa isabel do rio negro
# Processing Record 14 of Set 6 | chokurdakh
# Processing Record 15 of Set 6 | hasaki
# Processing Record 16 of Set 6 | marawi
# Processing Record 17 of Set 6 | souillac
# Processing Record 18 of Set 6 | inhambane
# Processing Record 19 of Set 6 | lompoc
# Processing Record 20 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 6 | saint-louis
# Processing Record 22 of Set 6 | karratha
# Processing Record 23 of Set 6 | jaciara
# Processing Record 24 of Set 6 | lakes entrance
# Processing Record 25 of Set 6 | walvis bay
# Processing Record 26 of Set 6 | ekhabi
# Processing Record 27 of Set 6 | mutare
# Processing Record 28 of Set 6 | sioux lookout
# Processing Record 29 of Set 6 | chihuahua
# Processing Record 30 of Set 6 | ajka
# Processing Record 31 of Set 6 | jalu
# Processing Record 32 of Set 6 | port blair
# Processing Record 33 of Set 6 | vostok
# Processing Record 34 of Set 6 | kruisfontein
# Processing Record 35 of Set 6 | paramonga
# Processing Record 36 of Set 6 | port hedland
# Processing Record 37 of Set 6 | correggio
# Processing Record 38 of Set 6 | ewa beach
# Processing Record 39 of Set 6 | kenai
# Processing Record 40 of Set 6 | jarjis
# City not found. Skipping...
# Processing Record 41 of Set 6 | chibombo
# Processing Record 42 of Set 6 | norman wells
# Processing Record 43 of Set 6 | alofi
# Processing Record 44 of Set 6 | ostuncalco
# Processing Record 45 of Set 6 | arlit
# Processing Record 46 of Set 6 | kharan
# Processing Record 47 of Set 6 | tanda
# Processing Record 48 of Set 6 | sawtell
# Processing Record 49 of Set 6 | soe
# Processing Record 50 of Set 6 | grand island
# Processing Record 1 of Set 7 | karatuzskoye
# Processing Record 2 of Set 7 | dawei
# Processing Record 3 of Set 7 | madison
# Processing Record 4 of Set 7 | bontang
# Processing Record 5 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 7 | guerrero negro
# Processing Record 7 of Set 7 | sechura
# Processing Record 8 of Set 7 | wasilla
# Processing Record 9 of Set 7 | mount gambier
# Processing Record 10 of Set 7 | trollhattan
# Processing Record 11 of Set 7 | te anau
# Processing Record 12 of Set 7 | ukiah
# Processing Record 13 of Set 7 | puerto escondido
# Processing Record 14 of Set 7 | otradnoye
# Processing Record 15 of Set 7 | san carlos
# Processing Record 16 of Set 7 | severnoye
# Processing Record 17 of Set 7 | harper
# Processing Record 18 of Set 7 | westport
# Processing Record 19 of Set 7 | magnitka
# Processing Record 20 of Set 7 | ondo
# Processing Record 21 of Set 7 | watsa
# Processing Record 22 of Set 7 | chapais
# Processing Record 23 of Set 7 | viedma
# Processing Record 24 of Set 7 | cherskiy
# Processing Record 25 of Set 7 | christchurch
# Processing Record 26 of Set 7 | quelimane
# Processing Record 27 of Set 7 | pangkalanbuun
# Processing Record 28 of Set 7 | isangel
# Processing Record 29 of Set 7 | kavieng
# Processing Record 30 of Set 7 | lima
# Processing Record 31 of Set 7 | tashara
# Processing Record 32 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 7 | yumen
# Processing Record 34 of Set 7 | keti bandar
# Processing Record 35 of Set 7 | yulara
# Processing Record 36 of Set 7 | tiarei
# Processing Record 37 of Set 7 | salalah
# Processing Record 38 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 7 | luena
# Processing Record 40 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 41 of Set 7 | tawau
# Processing Record 42 of Set 7 | bathsheba
# Processing Record 43 of Set 7 | kasangulu
# Processing Record 44 of Set 7 | lampazos de naranjo
# Processing Record 45 of Set 7 | sakaiminato
# Processing Record 46 of Set 7 | kaliua
# Processing Record 47 of Set 7 | bernalillo
# Processing Record 48 of Set 7 | birao
# Processing Record 49 of Set 7 | mersing
# Processing Record 50 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 8 | zhoucheng
# Processing Record 2 of Set 8 | arraial do cabo
# Processing Record 3 of Set 8 | sheridan
# Processing Record 4 of Set 8 | shache
# Processing Record 5 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 8 | killybegs
# Processing Record 7 of Set 8 | belem de sao francisco
# Processing Record 8 of Set 8 | rocha
# Processing Record 9 of Set 8 | namibe
# Processing Record 10 of Set 8 | punta alta
# Processing Record 11 of Set 8 | port elizabeth
# Processing Record 12 of Set 8 | tautira
# Processing Record 13 of Set 8 | arman
# Processing Record 14 of Set 8 | plouzane
# Processing Record 15 of Set 8 | oruro
# Processing Record 16 of Set 8 | yenotayevka
# Processing Record 17 of Set 8 | padang
# Processing Record 18 of Set 8 | kon tum
# Processing Record 19 of Set 8 | huilong
# Processing Record 20 of Set 8 | naze
# Processing Record 21 of Set 8 | swan hill
# Processing Record 22 of Set 8 | san roque
# Processing Record 23 of Set 8 | iracoubo
# Processing Record 24 of Set 8 | bonanza
# Processing Record 25 of Set 8 | farah
# Processing Record 26 of Set 8 | plettenberg bay
# Processing Record 27 of Set 8 | klaksvik
# Processing Record 28 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 8 | taoudenni
# Processing Record 30 of Set 8 | goderich
# Processing Record 31 of Set 8 | pervomaysk
# Processing Record 32 of Set 8 | faanui
# Processing Record 33 of Set 8 | gboko
# Processing Record 34 of Set 8 | ceres
# Processing Record 35 of Set 8 | narsaq
# Processing Record 36 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 37 of Set 8 | sierra vista
# Processing Record 38 of Set 8 | tiptur
# Processing Record 39 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 8 | anori
# Processing Record 41 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 8 | lyngdal
# Processing Record 43 of Set 8 | tasiilaq
# Processing Record 44 of Set 8 | olavarria
# Processing Record 45 of Set 8 | corn island
# Processing Record 46 of Set 8 | bismarck
# Processing Record 47 of Set 8 | matara
# Processing Record 48 of Set 8 | montclair
# Processing Record 49 of Set 8 | dharchula
# Processing Record 50 of Set 8 | cidreira
# Processing Record 1 of Set 9 | makakilo city
# Processing Record 2 of Set 9 | liman
# Processing Record 3 of Set 9 | mogadishu
# Processing Record 4 of Set 9 | la ronge
# Processing Record 5 of Set 9 | antofagasta
# Processing Record 6 of Set 9 | rochegda
# Processing Record 7 of Set 9 | cumana
# Processing Record 8 of Set 9 | monrovia
# Processing Record 9 of Set 9 | koslan
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | mount isa
# Processing Record 12 of Set 9 | chelyabinsk-40
# City not found. Skipping...
# Processing Record 13 of Set 9 | taunggyi
# Processing Record 14 of Set 9 | ikwiriri
# Processing Record 15 of Set 9 | fairbanks
# Processing Record 16 of Set 9 | dali
# Processing Record 17 of Set 9 | blagodatnoye
# Processing Record 18 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 19 of Set 9 | wencheng
# Processing Record 20 of Set 9 | vastseliina
# Processing Record 21 of Set 9 | nanortalik
# Processing Record 22 of Set 9 | shimoda
# Processing Record 23 of Set 9 | finschhafen
# Processing Record 24 of Set 9 | katangli
# Processing Record 25 of Set 9 | santa isabel
# Processing Record 26 of Set 9 | rio gallegos
# Processing Record 27 of Set 9 | buala
# Processing Record 28 of Set 9 | burica
# City not found. Skipping...
# Processing Record 29 of Set 9 | biltine
# Processing Record 30 of Set 9 | dauphin
# Processing Record 31 of Set 9 | talnakh
# Processing Record 32 of Set 9 | huarmey
# Processing Record 33 of Set 9 | imst
# Processing Record 34 of Set 9 | sorong
# Processing Record 35 of Set 9 | maniitsoq
# Processing Record 36 of Set 9 | solnechnyy
# Processing Record 37 of Set 9 | vila velha
# Processing Record 38 of Set 9 | praia
# Processing Record 39 of Set 9 | jiangkou
# Processing Record 40 of Set 9 | tual
# Processing Record 41 of Set 9 | roshchino
# Processing Record 42 of Set 9 | suntar
# Processing Record 43 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 9 | taltal
# Processing Record 45 of Set 9 | khash
# Processing Record 46 of Set 9 | dedougou
# Processing Record 47 of Set 9 | tomari
# Processing Record 48 of Set 9 | songjianghe
# Processing Record 49 of Set 9 | ozark
# Processing Record 50 of Set 9 | wonji
# City not found. Skipping...
# Processing Record 1 of Set 10 | ilulissat
# Processing Record 2 of Set 10 | kaele
# Processing Record 3 of Set 10 | sampit
# Processing Record 4 of Set 10 | kysyl-syr
# Processing Record 5 of Set 10 | nis
# Processing Record 6 of Set 10 | marzuq
# Processing Record 7 of Set 10 | talcahuano
# Processing Record 8 of Set 10 | grindavik
# Processing Record 9 of Set 10 | kuandian
# Processing Record 10 of Set 10 | hami
# Processing Record 11 of Set 10 | rantepao
# Processing Record 12 of Set 10 | bata
# Processing Record 13 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 10 | lons-le-saunier
# Processing Record 15 of Set 10 | sao joao da barra
# Processing Record 16 of Set 10 | brigantine
# Processing Record 17 of Set 10 | sur
# Processing Record 18 of Set 10 | newberg
# Processing Record 19 of Set 10 | dongsheng
# Processing Record 20 of Set 10 | whitehorse
# Processing Record 21 of Set 10 | mikhaylovka
# Processing Record 22 of Set 10 | atbasar
# Processing Record 23 of Set 10 | kurilsk
# Processing Record 24 of Set 10 | torquay
# Processing Record 25 of Set 10 | anito
# Processing Record 26 of Set 10 | hamilton
# Processing Record 27 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 28 of Set 10 | neka
# Processing Record 29 of Set 10 | teahupoo
# Processing Record 30 of Set 10 | asosa
# Processing Record 31 of Set 10 | boca de parita
# Processing Record 32 of Set 10 | sorgun
# Processing Record 33 of Set 10 | derzhavinsk
# Processing Record 34 of Set 10 | alugan
# Processing Record 35 of Set 10 | iki-burul
# Processing Record 36 of Set 10 | grand gaube
# Processing Record 37 of Set 10 | snasa
# Processing Record 38 of Set 10 | rawson
# Processing Record 39 of Set 10 | comodoro rivadavia
# Processing Record 40 of Set 10 | srednekolymsk
# Processing Record 41 of Set 10 | curaca
# Processing Record 42 of Set 10 | hargeysa
# Processing Record 43 of Set 10 | mirnyy
# Processing Record 44 of Set 10 | tazmalt
# Processing Record 45 of Set 10 | komsomolskiy
# Processing Record 46 of Set 10 | shaoguan
# Processing Record 47 of Set 10 | tilichiki
# Processing Record 48 of Set 10 | cascais
# Processing Record 49 of Set 10 | seymchan
# Processing Record 50 of Set 10 | antalaha
# Processing Record 1 of Set 11 | havre-saint-pierre
# Processing Record 2 of Set 11 | nara
# Processing Record 3 of Set 11 | sakakah
# Processing Record 4 of Set 11 | concepcion del oro
# Processing Record 5 of Set 11 | ambon
# Processing Record 6 of Set 11 | libreville
# Processing Record 7 of Set 11 | fallon
# Processing Record 8 of Set 11 | aksha
# Processing Record 9 of Set 11 | hoquiam
# Processing Record 10 of Set 11 | gambela
# Processing Record 11 of Set 11 | aktau
# Processing Record 12 of Set 11 | port-cartier
# Processing Record 13 of Set 11 | gouyave
# Processing Record 14 of Set 11 | kuusamo
# Processing Record 15 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 11 | kieta
# Processing Record 17 of Set 11 | khandbari
# Processing Record 18 of Set 11 | tommot
# Processing Record 19 of Set 11 | buta
# Processing Record 20 of Set 11 | strezhevoy
# Processing Record 21 of Set 11 | yarkovo
# Processing Record 22 of Set 11 | rapid city
# Processing Record 23 of Set 11 | chik
# Processing Record 24 of Set 11 | diffa
# Processing Record 25 of Set 11 | yazykovo
# Processing Record 26 of Set 11 | kahului
# Processing Record 27 of Set 11 | turukhansk
# Processing Record 28 of Set 11 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 29 of Set 11 | vanimo
# Processing Record 30 of Set 11 | tiznit
# Processing Record 31 of Set 11 | acapulco
# Processing Record 32 of Set 11 | san benito abad
# Processing Record 33 of Set 11 | kiama
# Processing Record 34 of Set 11 | nederland
# Processing Record 35 of Set 11 | champerico
# Processing Record 36 of Set 11 | pasighat
# Processing Record 37 of Set 11 | mirador
# Processing Record 38 of Set 11 | kalmunai
# Processing Record 39 of Set 11 | kaduqli
# Processing Record 40 of Set 11 | katherine
# Processing Record 41 of Set 11 | praya
# Processing Record 42 of Set 11 | margate
# Processing Record 43 of Set 11 | muros
# Processing Record 44 of Set 11 | baculin
# Processing Record 45 of Set 11 | goya
# Processing Record 46 of Set 11 | stettler
# Processing Record 47 of Set 11 | mayo
# Processing Record 48 of Set 11 | aktash
# Processing Record 49 of Set 11 | bonthe
# Processing Record 50 of Set 11 | richards bay
# Processing Record 1 of Set 12 | melo
# Processing Record 2 of Set 12 | kamaishi
# Processing Record 3 of Set 12 | uglovskoye
# Processing Record 4 of Set 12 | deputatskiy
# Processing Record 5 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 12 | makung
# City not found. Skipping...
# Processing Record 7 of Set 12 | motril
# Processing Record 8 of Set 12 | ekibastuz
# Processing Record 9 of Set 12 | doha
# Processing Record 10 of Set 12 | asau
# Processing Record 11 of Set 12 | russell
# Processing Record 12 of Set 12 | gwadar
# Processing Record 13 of Set 12 | aklavik
# Processing Record 14 of Set 12 | sao lourenco do sul
# Processing Record 15 of Set 12 | wagga wagga
# Processing Record 16 of Set 12 | lucapa
# Processing Record 17 of Set 12 | gamba
# Processing Record 18 of Set 12 | mareeba
# Processing Record 19 of Set 12 | gazalkent
# Processing Record 20 of Set 12 | alibag
# Processing Record 21 of Set 12 | tuatapere
# Processing Record 22 of Set 12 | niquelandia
# Processing Record 23 of Set 12 | oleksandrivka
# Processing Record 24 of Set 12 | riaba
# City not found. Skipping...
# Processing Record 25 of Set 12 | port arthur
# Processing Record 26 of Set 12 | usakos
# Processing Record 27 of Set 12 | syracuse
# Processing Record 28 of Set 12 | haines junction
# Processing Record 29 of Set 12 | praia da vitoria
# Processing Record 30 of Set 12 | bluefield
# Processing Record 31 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 32 of Set 12 | lata
# Processing Record 33 of Set 12 | nouakchott
# Processing Record 34 of Set 12 | peddapuram
# Processing Record 35 of Set 12 | cizre
# Processing Record 36 of Set 12 | pierre
# Processing Record 37 of Set 12 | karasjok
# Processing Record 38 of Set 12 | panagjuriste
# City not found. Skipping...
# Processing Record 39 of Set 12 | vagamo
# Processing Record 40 of Set 12 | rajpura
# Processing Record 41 of Set 12 | ponta delgada
# Processing Record 42 of Set 12 | hrodna
# Processing Record 43 of Set 12 | turka
# Processing Record 44 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 12 | tsumeb
# Processing Record 46 of Set 12 | luzhou
# Processing Record 47 of Set 12 | tete
# Processing Record 48 of Set 12 | makkaveyevo
# Processing Record 49 of Set 12 | port macquarie
# Processing Record 50 of Set 12 | cheremisinovo
# Processing Record 1 of Set 13 | saint-joseph
# Processing Record 2 of Set 13 | umm jarr
# City not found. Skipping...
# Processing Record 3 of Set 13 | pokrovsk
# Processing Record 4 of Set 13 | igra
# Processing Record 5 of Set 13 | high rock
# Processing Record 6 of Set 13 | olafsvik
# Processing Record 7 of Set 13 | muisne
# Processing Record 8 of Set 13 | caravelas
# Processing Record 9 of Set 13 | kawalu
# Processing Record 10 of Set 13 | almaznyy
# Processing Record 11 of Set 13 | cairns
# Processing Record 12 of Set 13 | zyryanka
# Processing Record 13 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 13 | changde
# Processing Record 15 of Set 13 | gorkovskoye
# City not found. Skipping...
# Processing Record 16 of Set 13 | abu samrah
# Processing Record 17 of Set 13 | doka
# Processing Record 18 of Set 13 | samarai
# Processing Record 19 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 13 | vao
# Processing Record 21 of Set 13 | broken hill
# Processing Record 22 of Set 13 | ilo
# Processing Record 23 of Set 13 | wadi musa
# Processing Record 24 of Set 13 | tynda
# Processing Record 25 of Set 13 | kosh-agach
# Processing Record 26 of Set 13 | daoukro
# Processing Record 27 of Set 13 | nautla
# Processing Record 28 of Set 13 | zhuhai
# Processing Record 29 of Set 13 | riyadh
# Processing Record 30 of Set 13 | san martin jilotepeque
# Processing Record 31 of Set 13 | chirongui
# Processing Record 32 of Set 13 | vryburg
# Processing Record 33 of Set 13 | tottori
# Processing Record 34 of Set 13 | bin qirdan
# Processing Record 35 of Set 13 | la orilla
# Processing Record 36 of Set 13 | welkom
# Processing Record 37 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 13 | kailua
# Processing Record 39 of Set 13 | votice
# Processing Record 40 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 41 of Set 13 | morro bay
# Processing Record 42 of Set 13 | brae
# Processing Record 43 of Set 13 | pacific grove
# Processing Record 44 of Set 13 | ibirama
# Processing Record 45 of Set 13 | itarema
# Processing Record 46 of Set 13 | prince george
# Processing Record 47 of Set 13 | lazarev
# Processing Record 48 of Set 13 | sibolga
# Processing Record 49 of Set 13 | jorpeland
# Processing Record 50 of Set 13 | champasak
# Processing Record 1 of Set 14 | tuy hoa
# Processing Record 2 of Set 14 | rawatsar
# Processing Record 3 of Set 14 | mackay
# Processing Record 4 of Set 14 | sembe
# Processing Record 5 of Set 14 | kirensk
# Processing Record 6 of Set 14 | assare
# Processing Record 7 of Set 14 | fukiage
# Processing Record 8 of Set 14 | javanrud
# Processing Record 9 of Set 14 | aksarka
# Processing Record 10 of Set 14 | puerto penasco
# Processing Record 11 of Set 14 | boa vista
# Processing Record 12 of Set 14 | neuquen
# Processing Record 13 of Set 14 | misratah
# Processing Record 14 of Set 14 | atherton
# Processing Record 15 of Set 14 | pirovskoye
# Processing Record 16 of Set 14 | poyarkovo
# Processing Record 17 of Set 14 | truth or consequences
# Processing Record 18 of Set 14 | sri aman
# Processing Record 19 of Set 14 | kananga
# Processing Record 20 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 14 | kewanee
# Processing Record 22 of Set 14 | san pedro de macoris
# Processing Record 23 of Set 14 | saint-pierre
# Processing Record 24 of Set 14 | loei
# Processing Record 25 of Set 14 | kendari
# Processing Record 26 of Set 14 | banepa
# Processing Record 27 of Set 14 | ulladulla
# Processing Record 28 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 29 of Set 14 | otjiwarongo
# Processing Record 30 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 14 | nizhniy odes
# Processing Record 32 of Set 14 | kusu
# Processing Record 33 of Set 14 | udachnyy
# Processing Record 34 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 14 | valdosta
# Processing Record 36 of Set 14 | korla
# Processing Record 37 of Set 14 | nuuk
# Processing Record 38 of Set 14 | bubaque
# Processing Record 39 of Set 14 | port-gentil
# Processing Record 40 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 14 | chabahar
# Processing Record 42 of Set 14 | havoysund
# Processing Record 43 of Set 14 | velikovechnoye
# Processing Record 44 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 14 | parnu-jaagupi
# Processing Record 46 of Set 14 | glubokoe
# City not found. Skipping...
# Processing Record 47 of Set 14 | sidney
# Processing Record 48 of Set 14 | kohlu
# Processing Record 49 of Set 14 | sobolevo
# Processing Record 50 of Set 14 | felipe carrillo puerto
# Processing Record 1 of Set 15 | funadhoo
# Processing Record 2 of Set 15 | evansville
# Processing Record 3 of Set 15 | boddam
# Processing Record 4 of Set 15 | shibata
# Processing Record 5 of Set 15 | fortuna
# Processing Record 6 of Set 15 | kushiro
# Processing Record 7 of Set 15 | deming
# Processing Record 8 of Set 15 | parfenyevo
# Processing Record 9 of Set 15 | bandarbeyla
# Processing Record 10 of Set 15 | amethi
# Processing Record 11 of Set 15 | pacifica
# Processing Record 12 of Set 15 | unye
# City not found. Skipping...
# Processing Record 13 of Set 15 | mugur-aksy
# Processing Record 14 of Set 15 | murray bridge
# Processing Record 15 of Set 15 | hay river
# Processing Record 16 of Set 15 | gladstone
# Processing Record 17 of Set 15 | inuvik
# Processing Record 18 of Set 15 | yabelo
# Processing Record 19 of Set 15 | calamar
# Processing Record 20 of Set 15 | ucluelet
# Processing Record 21 of Set 15 | prince rupert
# Processing Record 22 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 23 of Set 15 | balykshi
# Processing Record 24 of Set 15 | zabol
# Processing Record 25 of Set 15 | quatre cocos
# Processing Record 26 of Set 15 | kloulklubed
# Processing Record 27 of Set 15 | zhanakorgan
# Processing Record 28 of Set 15 | wau
# Processing Record 29 of Set 15 | imbituba
# Processing Record 30 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 15 | mwense
# Processing Record 32 of Set 15 | lavrentiya
# Processing Record 33 of Set 15 | howard springs
# Processing Record 34 of Set 15 | santiago
# Processing Record 35 of Set 15 | libertador general san martin
# Processing Record 36 of Set 15 | manjo
# Processing Record 37 of Set 15 | gat
# Processing Record 38 of Set 15 | hualmay
# Processing Record 39 of Set 15 | kondinskoye
# Processing Record 40 of Set 15 | labuan
# Processing Record 41 of Set 15 | muzhi
# Processing Record 42 of Set 15 | cuamba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#7 Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Jamestown      US  42.0970  -79.2353     74.52        83          90
# 1       Vaini      TO -21.2000 -175.2000     78.96        89          75
# 2  Butaritari      KI   3.0707  172.7902     82.81        70          78
# 3       Vardo      NO  70.3705   31.1107     37.60        76         100
# 4     Emerald      AU -23.5333  148.1667     74.98        15           0
# 5     Ushuaia      AR -54.8000  -68.3000     49.66        50          40
# 6        Biak      ID  -0.9131  122.8766     79.59        82          84
# 7      Dikson      RU  73.5069   80.5464     28.99        90         100
# 8   Joshimath      IN  30.5667   79.5667     59.40        27           0
# 9      Atuona      PF  -9.8000 -139.0333     77.85        78          22
#
#    Wind Speed Current Description
# 0        6.91     overcast clouds
# 1        5.75       broken clouds
# 2        9.75       broken clouds
# 3       15.57          light rain
# 4        6.91           clear sky
# 5       20.71          light rain
# 6        1.97       broken clouds
# 7        6.80     overcast clouds
# 8        6.89           clear sky
# 9       17.92          light rain

# %%
#8 Export DataFrame as a CSV file
city_data_df.to_csv('WeatherPy_Database.csv')
